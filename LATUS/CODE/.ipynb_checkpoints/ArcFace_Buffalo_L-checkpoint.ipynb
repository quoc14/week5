# %%
from insightface.app import FaceAnalysis
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from insightface.app import FaceAnalysis
import cv2
import os
import numpy as np

# %%
def calc_cost(embedding1, embedding2):
    return cosine_similarity([embedding1], [embedding2])[0][0]

# %%
app = FaceAnalysis(name="Buffalo_l",  providers=['CPUExecutionProvider'])
app.prepare(ctx_id=0, det_size=(640, 640))
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ATUS/.insightface\models\Buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ATUS/.insightface\models\Buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ATUS/.insightface\models\Buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ATUS/.insightface\models\Buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\ATUS/.insightface\models\Buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
def toembeddings(img):
    return app.get(img)

# %%
def init_embeddings(pathdata, testsize):
    # Đường dẫn tới bộ dữ liệu LFW
    # lfw_path = r"C:\Users\ATUS\Desktop\LUONG ANH TU\Database\lfw"
    # Lưu embeddings của tất cả các khuôn mặt
    embeddings = []
    labels = []

    # Lặp qua từng thư mục trong bộ dữ liệu LFW (mỗi thư mục là một người)
    for person_name in os.listdir(pathdata):
        if (testsize == 0): break
        person_path = os.path.join(pathdata, person_name)
        if os.path.isdir(person_path):
            # Lặp qua từng ảnh của người đó
            for img_name in os.listdir(person_path):
                if (testsize == 0): break
                img_path = os.path.join(person_path, img_name)
                # Đọc ảnh và lấy embedding từ mô hình
                img = cv2.imread(img_path)
                faces = toembeddings(img)
                if len(faces) > 0:
                    face_embedding = faces[0].embedding
                    print(f"{testsize} {person_name}")
                    embeddings.append(face_embedding)
                    labels.append(person_name)
                    testsize-=1
    return embeddings, labels

# %%
embeddings, labels = init_embeddings(r"C:\Users\ATUS\Desktop\LUONG ANH TU\Database\lfw", 200)
# Out:
# C:\Users\ATUS\AppData\Local\Programs\Python\Python311\Lib\site-packages\insightface\utils\transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# 200 Aaron_Eckhart
# 199 Aaron_Guiel
# 198 Aaron_Patterson
# 197 Aaron_Peirsol
# 196 Aaron_Peirsol
# 195 Aaron_Peirsol
# 194 Aaron_Peirsol
# 193 Aaron_Pena
# 192 Aaron_Sorkin
# 191 Aaron_Sorkin
# 190 Aaron_Tippin
# 189 Abbas_Kiarostami
# 188 Abba_Eban
# 187 Abdel_Aziz_Al-Hakim
# 186 Abdel_Madi_Shabneh
# 185 Abdel_Nasser_Assidi
# 184 Abdel_Nasser_Assidi
# 183 Abdoulaye_Wade
# 182 Abdoulaye_Wade
# 181 Abdoulaye_Wade
# 180 Abdoulaye_Wade
# 179 Abdulaziz_Kamilov
# 178 Abdullah
# 177 Abdullah
# 176 Abdullah
# 175 Abdullah
# 174 Abdullah_Ahmad_Badawi
# 173 Abdullah_al-Attiyah
# 172 Abdullah_al-Attiyah
# 171 Abdullah_al-Attiyah
# 170 Abdullah_Gul
# 169 Abdullah_Gul
# 168 Abdullah_Gul
# 167 Abdullah_Gul
# 166 Abdullah_Gul
# 165 Abdullah_Gul
# 164 Abdullah_Gul
# 163 Abdullah_Gul
# 162 Abdullah_Gul
# 161 Abdullah_Gul
# 160 Abdullah_Gul
# 159 Abdullah_Gul
# 158 Abdullah_Gul
# 157 Abdullah_Gul
# 156 Abdullah_Gul
# 155 Abdullah_Gul
# 154 Abdullah_Gul
# 153 Abdullah_Gul
# 152 Abdullah_Gul
# 151 Abdullah_Nasseef
# 150 Abdullatif_Sener
# 149 Abdullatif_Sener
# 148 Abdul_Majeed_Shobokshi
# 147 Abdul_Rahman
# 146 Abel_Aguilar
# 145 Abel_Pacheco
# 144 Abel_Pacheco
# 143 Abel_Pacheco
# 142 Abel_Pacheco
# 141 Abid_Hamid_Mahmud_Al-Tikriti
# 140 Abid_Hamid_Mahmud_Al-Tikriti
# 139 Abid_Hamid_Mahmud_Al-Tikriti
# 138 Abner_Martinez
# 137 Abraham_Foxman
# 136 Aby_Har-Even
# 135 Adam_Ant
# 134 Adam_Freier
# 133 Adam_Herbert
# 132 Adam_Kennedy
# 131 Adam_Mair
# 130 Adam_Rich
# 129 Adam_Sandler
# 128 Adam_Sandler
# 127 Adam_Sandler
# 126 Adam_Sandler
# 125 Adam_Scott
# 124 Adam_Scott
# 123 Adelina_Avila
# 122 Adel_Al-Jubeir
# 121 Adel_Al-Jubeir
# 120 Adel_Al-Jubeir
# 119 Adisai_Bodharamik
# 118 Adolfo_Aguilar_Zinser
# 117 Adolfo_Aguilar_Zinser
# 116 Adolfo_Aguilar_Zinser
# 115 Adolfo_Rodriguez_Saa
# 114 Adolfo_Rodriguez_Saa
# 113 Adoor_Gopalakarishnan
# 112 Adriana_Lima
# 111 Adriana_Perez_Navarro
# 110 Adrianna_Zuzic
# 109 Adrian_Annus
# 108 Adrian_Fernandez
# 107 Adrian_McPherson
# 106 Adrian_McPherson
# 105 Adrian_Murrell
# 104 Adrian_Nastase
# 103 Adrian_Nastase
# 102 Adrien_Brody
# 101 Adrien_Brody
# 100 Adrien_Brody
# 99 Adrien_Brody
# 98 Adrien_Brody
# 97 Adrien_Brody
# 96 Adrien_Brody
# 95 Adrien_Brody
# 94 Adrien_Brody
# 93 Adrien_Brody
# 92 Adrien_Brody
# 91 Adrien_Brody
# 90 Afton_Smith
# 89 Agbani_Darego
# 88 Agnelo_Queiroz
# 87 Agnes_Bruckner
# 86 Ahmad_Jbarah
# 85 Ahmad_Masood
# 84 Ahmad_Masood
# 83 Ahmed_Ahmed
# 82 Ahmed_Chalabi
# 81 Ahmed_Chalabi
# 80 Ahmed_Chalabi
# 79 Ahmed_Chalabi
# 78 Ahmed_Chalabi
# 77 Ahmed_Ghazi
# 76 Ahmed_Ibrahim_Bilal
# 75 Ahmed_Lopez
# 74 Ahmed_Qureia
# 73 Ahmet_Demir
# 72 Ahmet_Necdet_Sezer
# 71 Ahmet_Necdet_Sezer
# 70 Aicha_El_Ouafi
# 69 Aicha_El_Ouafi
# 68 Aicha_El_Ouafi
# 67 Aidan_Quinn
# 66 Aileen_Riggin_Soule
# 65 Ainsworth_Dyer
# 64 Ain_Seppik
# 63 Aishwarya_Rai
# 62 Aitor_Gonzalez
# 61 Aitor_Gonzalez
# 60 Aiysha_Smith
# 59 Ai_Sugiyama
# 58 Ai_Sugiyama
# 57 Ai_Sugiyama
# 56 Ai_Sugiyama
# 55 Ai_Sugiyama
# 54 Ajit_Agarkar
# 53 AJ_Cook
# 52 AJ_Lamas
# 51 Akbar_Al_Baker
# 50 Akbar_Hashemi_Rafsanjani
# 49 Akbar_Hashemi_Rafsanjani
# 48 Akbar_Hashemi_Rafsanjani
# 47 Akhmed_Zakayev
# 46 Akhmed_Zakayev
# 45 Akhmed_Zakayev
# 44 Akiko_Morigami
# 43 Akmal_Taher
# 42 Alain_Cervantes
# 41 Alain_Ducasse
# 40 Alanis_Morissette
# 39 Alanna_Ubach
# 38 Alan_Ball
# 37 Alan_Ball
# 36 Alan_Dershowitz
# 35 Alan_Dreher
# 34 Alan_Greenspan
# 33 Alan_Greenspan
# 32 Alan_Greenspan
# 31 Alan_Greenspan
# 30 Alan_Greenspan
# 29 Alan_Greer
# 28 Alan_Jackson
# 27 Alan_Mulally
# 26 Alan_Mulally
# 25 Alan_Stonecipher
# 24 Alan_Tang_Kwong-wing
# 23 Alan_Trammell
# 22 Alan_Zemaitis
# 21 Alastair_Campbell
# 20 Alastair_Campbell
# 19 Alastair_Campbell
# 18 Alastair_Campbell
# 17 Alastair_Campbell
# 16 Alastair_Johnston
# 15 Albaro_Recoba
# 14 Alberta_Lee
# 13 Alberto_Acosta
# 12 Alberto_Fujimori
# 11 Alberto_Fujimori
# 10 Alberto_Gonzales
# 9 Alberto_Ruiz_Gallardon
# 8 Alberto_Ruiz_Gallardon
# 7 Alberto_Sordi
# 6 Albert_Brooks
# 5 Albert_Costa
# 4 Albert_Costa
# 3 Albert_Costa
# 2 Albert_Costa
# 1 Albert_Costa
